# %% [markdown]
# # 01A - Data Import, Toronto Bike Share

# %% [markdown]
# ## Import relevant libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import requests
import json

# %% [markdown]
# ---

# %% [markdown]
# ## Using API - get Station and Pricing Data

# %%
# Toronto Open Data is stored in a CKAN instance. It's APIs are documented here:
# https://docs.ckan.org/en/latest/api/
# To hit our API, you'll be making requests to:
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"

# Datasets are called "packages". Each package can contain many "resources"
# To retrieve the metadata for this package and its resources, use the package name in this page's URL:
url = base_url + "/api/3/action/package_show"
params = { "id": "bike-share-toronto"}
package = requests.get(url, params = params).json()

# To get resource data:
for idx, resource in enumerate(package["result"]["resources"]):

    # To get metadata for non datastore_active resources:
    if not resource["datastore_active"]:
        url = base_url + "/api/3/action/resource_show?id=" + resource["id"]
        resource_metadata = requests.get(url).json()
        print(resource_metadata)
             # From here, you can use the "url" attribute to download this file
        
        print("") # space out results
        print("Print URL:")
        print(resource_metadata['result']['url'])
        print("") # space out results
# Out:
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=resource_show', 'success': True, 'result': {'cache_last_updated': None, 'cache_url': None, 'created': '2019-07-23T16:40:17.467193', 'datastore_active': False, 'format': 'JSON', 'hash': '', 'id': '5c1c2c06-d27f-47b7-ae82-926a6d23d76f', 'is_datastore_cache_file': False, 'is_preview': False, 'last_modified': '2019-07-23T16:40:17.427058', 'metadata_modified': '2022-03-10T16:24:04.865406', 'mimetype': 'application/json', 'mimetype_inner': None, 'name': 'bike-share-json', 'package_id': '2b44db0d-eea9-442d-b038-79335368ad5a', 'position': 0, 'resource_type': None, 'revision_id': 'e19f02c5-3513-46df-a4f6-375e4e530133', 'size': 577, 'state': 'active', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2b44db0d-eea9-442d-b038-79335368ad5a/resource/5c1c2c06-d27f-47b7-ae82-926a6d23d76f/download/bike-share-json.json', 'url_type': 'upload'}}
#
# Print URL:
# https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2b44db0d-eea9-442d-b038-79335368ad5a/resource/5c1c2c06-d27f-47b7-ae82-926a6d23d76f/download/bike-share-json.json
#
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=resource_show', 'success': True, 'result': {'cache_last_updated': None, 'cache_url': None, 'created': '2019-07-23T16:40:18.280959', 'datastore_active': False, 'format': 'JSON', 'hash': '', 'id': 'b69873a1-c180-4ccd-a970-514e434b4971', 'is_datastore_cache_file': False, 'is_preview': False, 'last_modified': '2019-07-23T16:40:18.215372', 'metadata_modified': '2022-03-10T16:24:06.148332', 'mimetype': 'application/json', 'mimetype_inner': None, 'name': 'bike-share-gbfs-general-bikeshare-feed-specification', 'package_id': '2b44db0d-eea9-442d-b038-79335368ad5a', 'position': 1, 'resource_type': None, 'revision_id': 'e19f02c5-3513-46df-a4f6-375e4e530133', 'size': 577, 'state': 'active', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2b44db0d-eea9-442d-b038-79335368ad5a/resource/b69873a1-c180-4ccd-a970-514e434b4971/download/bike-share-gbfs-general-bikeshare-feed-specification.json', 'url_type': 'upload'}}
#
# Print URL:
# https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2b44db0d-eea9-442d-b038-79335368ad5a/resource/b69873a1-c180-4ccd-a970-514e434b4971/download/bike-share-gbfs-general-bikeshare-feed-specification.json
#
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=resource_show', 'success': True, 'result': {'cache_last_updated': None, 'cache_url': None, 'created': '2019-07-23T16:40:19.138864', 'datastore_active': False, 'format': 'WEB', 'hash': '', 'id': '2eb37596-96a7-4379-b334-a47a396e9ac3', 'is_datastore_cache_file': False, 'is_preview': True, 'last_modified': '2019-07-23T16:40:19.084648', 'metadata_modified': '2022-03-10T16:24:06.601572', 'mimetype': 'application/json', 'mimetype_inner': None, 'name': 'gbfs-documentation', 'package_id': '2b44db0d-eea9-442d-b038-79335368ad5a', 'position': 2, 'resource_type': None, 'revision_id': '54d4b35d-985a-4a2a-9fc6-cf96a15d870e', 'size': 116702, 'state': 'active', 'url': 'https://github.com/NABSA/gbfs', 'url_type': ''}}
#
# Print URL:
# https://github.com/NABSA/gbfs
#
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=resource_show', 'success': True, 'result': {'cache_last_updated': None, 'cache_url': None, 'created': '2019-07-23T16:40:19.981837', 'datastore_active': False, 'format': 'TXT', 'hash': '', 'id': '5ee32dcb-3f4d-4dfe-a3ad-e27f2c13b5a3', 'is_datastore_cache_file': False, 'is_preview': False, 'last_modified': '2019-07-23T16:40:19.920680', 'metadata_modified': '2022-03-10T16:24:08.013740', 'mimetype': 'text/plain', 'mimetype_inner': None, 'name': 'bike-share-stations-readme', 'package_id': '2b44db0d-eea9-442d-b038-79335368ad5a', 'position': 3, 'resource_type': None, 'revision_id': 'e19f02c5-3513-46df-a4f6-375e4e530133', 'size': 1701, 'state': 'active', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2b44db0d-eea9-442d-b038-79335368ad5a/resource/5ee32dcb-3f4d-4dfe-a3ad-e27f2c13b5a3/download/bike-share-stations-readme.txt', 'url_type': 'upload'}}
#
# Print URL:
# https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2b44db0d-eea9-442d-b038-79335368ad5a/resource/5ee32dcb-3f4d-4dfe-a3ad-e27f2c13b5a3/download/bike-share-stations-readme.txt

# %%
# Get URls within JSON with links to datasets in JSON 
r = requests.get('https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2b44db0d-eea9-442d-b038-79335368ad5a/resource/5c1c2c06-d27f-47b7-ae82-926a6d23d76f/download/bike-share-json.json').json()

r
# Out:
# {'last_updated': 1563373889,
#  'ttl': 24,
#  'data': {'en': {'feeds': [{'name': 'system regions',
#      'url': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_regions'},
#     {'name': 'system_information',
#      'url': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_information'},
#     {'name': 'station_information',
#      'url': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information'},
#     {'name': 'station_status',
#      'url': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_status'},
#     {'name': 'system_pricing_plans',
#      'url': 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_pricing_plans'}]}}}

# %% [markdown]
# ---

# %% [markdown]
# ### Station Information

# %%
# Visualize Station Dataset

r = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information').json()

r
# Out:
# {'last_updated': 1706414211,
#  'ttl': 22,
#  'data': {'stations': [{'station_id': '7000',
#     'name': 'Fort York  Blvd / Capreol Ct',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.639832,
#     'lon': -79.395954,
#     'altitude': 0.0,
#     'address': 'Fort York  Blvd / Capreol Ct',
#     'capacity': 35,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9607',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7001',
#     'name': 'Wellesley Station Green P',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 43.66496415990742,
#     'lon': -79.38355031526893,
#     'altitude': 0.0,
#     'address': 'Yonge / Wellesley',
#     'post_code': 'M4Y 1G7',
#     'capacity': 23,
#     'is_charging_station': True,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-617-9576',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7002',
#     'name': 'St. George St / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.667333,
#     'lon': -79.399429,
#     'altitude': 0.0,
#     'address': 'St. George St / Bloor St W',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9615',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7003',
#     'name': 'Madison Ave / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.667158,
#     'lon': -79.402761,
#     'altitude': None,
#     'address': 'Madison Ave / Bloor St W',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-631-4587',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7005',
#     'name': 'King St W / York St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6480008,
#     'lon': -79.383177,
#     'altitude': 0.0,
#     'address': 'King St W / York St',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9693',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7006',
#     'name': 'Bay St / College St (East Side)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.660439,
#     'lon': -79.385525,
#     'altitude': 0.0,
#     'address': 'Bay St / College St (East Side)',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7006-7235'],
#     'obcn': '416-569-2349',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7007',
#     'name': 'College St / Huron St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.658148,
#     'lon': -79.398167,
#     'altitude': 0.0,
#     'address': 'College St / Huron St',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-625-3582',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7008',
#     'name': "Wellesley St W / Queen's Park Cres",
#     'physical_configuration': 'REGULAR',
#     'lat': 43.663376,
#     'lon': -79.392125,
#     'altitude': 0.0,
#     'address': "Wellesley St W / Queen's Park Cres",
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9648',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7009',
#     'name': 'King St E / Jarvis St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650325,
#     'lon': -79.372287,
#     'altitude': 0.0,
#     'address': 'King St E / Jarvis St',
#     'capacity': 25,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-620-8649',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7010',
#     'name': 'King St W / Spadina Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645323,
#     'lon': -79.395003,
#     'altitude': 0.0,
#     'address': 'King St W / Spadina Ave',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-202-6537',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7012',
#     'name': 'Elizabeth St / Edward St (Bus Terminal)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656026,
#     'lon': -79.385327,
#     'altitude': 0.0,
#     'address': 'Elizabeth St / Edward St (Bus Terminal)',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9665',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7013',
#     'name': 'Scott St / The Esplanade',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64659663170443,
#     'lon': -79.37530913867988,
#     'altitude': 0.0,
#     'address': 'Scott St / The Esplanade',
#     'post_code': 'M5E 1Z4',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7375-7013'],
#     'obcn': '416-666-6440',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7014',
#     'name': 'Sherbourne St / Carlton St (Allan Gardens)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.663102,
#     'lon': -79.373181,
#     'altitude': 0.0,
#     'address': 'Sherbourne St / Carlton St (Allan Gardens)',
#     'capacity': 17,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-710-6764',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7015',
#     'name': 'King St W / Bay St (West Side)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64852,
#     'lon': -79.380576,
#     'altitude': 0.0,
#     'address': 'King St W / Bay St (West Side)',
#     'capacity': 39,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'is_valet_station': False,
#     'groups': [],
#     'obcn': '416-671-7595',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7016',
#     'name': 'Bay St / Queens Quay W (Ferry Terminal)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640978,
#     'lon': -79.376785,
#     'altitude': 0.0,
#     'address': 'Bay St / Queens Quay W (Ferry Terminal)',
#     'post_code': 'M5J',
#     'capacity': 35,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-271-1378',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7017',
#     'name': 'Widmer St / Adelaide St W',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.647547634759206,
#     'lon': -79.39155200496292,
#     'altitude': 0.0,
#     'address': 'Widmer St / Adelaide St W',
#     'post_code': 'M5V 1J9',
#     'capacity': 12,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': ['P7017-7102'],
#     'obcn': '647-631-9958',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7018',
#     'name': 'Bremner Blvd / Rees St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.641529,
#     'lon': -79.386741,
#     'altitude': 0.0,
#     'address': 'Bremner Blvd / Rees St',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'is_valet_station': False,
#     'groups': [],
#     'obcn': '647-669-0947',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7019',
#     'name': 'Temperance St Station',
#     'physical_configuration': 'VAULT',
#     'lat': 43.650945,
#     'lon': -79.379498,
#     'altitude': 0.0,
#     'address': 'Temperance St. Station',
#     'post_code': 'M5H 1Y6',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '9 Temperance St .',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7020',
#     'name': 'Phoebe St / Spadina Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650033,
#     'lon': -79.396555,
#     'altitude': None,
#     'address': 'Phoebe St / Spadina Ave',
#     'capacity': 33,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-621-5766',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7021',
#     'name': 'Bay St / Albert St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.653264,
#     'lon': -79.382458,
#     'altitude': 0.0,
#     'address': 'Bay St / Albert St',
#     'capacity': 35,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9652',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7022',
#     'name': 'Simcoe St / Queen St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.65049,
#     'lon': -79.3873,
#     'altitude': None,
#     'address': 'Simcoe St / Queen St W',
#     'post_code': 'm5v1z5',
#     'capacity': 39,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-625-3265',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7023',
#     'name': 'College St / Borden St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6571,
#     'lon': -79.4056,
#     'altitude': 0.0,
#     'address': 'College St / Borden St',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7023-7078'],
#     'obcn': '647-643-9629',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7024',
#     'name': 'Dundonald St / Church St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66663,
#     'lon': -79.38148,
#     'altitude': 0.0,
#     'address': 'Dundonald St / Church St',
#     'capacity': 39,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7241-7024'],
#     'obcn': '647-631-9859',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7025',
#     'name': 'Ted Rogers Way / Bloor St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671293,
#     'lon': -79.380471,
#     'altitude': 0.0,
#     'address': 'Ted Rogers Way / Bloor St E',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-631-9970',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7026',
#     'name': 'Bay St / St. Joseph St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.665527,
#     'lon': -79.387499,
#     'altitude': None,
#     'address': 'Bay St / St. Joseph St',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7274-7026'],
#     'obcn': '416-666-0783',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7027',
#     'name': 'Beverley  St / Dundas St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652823,
#     'lon': -79.393388,
#     'altitude': 0.0,
#     'address': 'Beverley  St / Dundas St W',
#     'capacity': 31,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-621-6739',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7028',
#     'name': 'Gould St / Mutual St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6582,
#     'lon': -79.3768,
#     'altitude': None,
#     'address': 'Gould St / Mutual St',
#     'capacity': 31,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-560-7261',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7029',
#     'name': 'Bay St / Bloor St W (East Side)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66943,
#     'lon': -79.38915,
#     'altitude': 0.0,
#     'address': '1199 Bay St',
#     'post_code': 'M6G1X2',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-669-3457',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7030',
#     'name': 'Bay St / Wellesley St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.664088,
#     'lon': -79.387095,
#     'altitude': None,
#     'address': 'Bay St / Wellesley St W',
#     'capacity': 51,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'is_valet_station': False,
#     'groups': [],
#     'obcn': '647-643-9612',
#     'nearby_distance': 1609.34,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7031',
#     'name': 'Jarvis St / Isabella St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.668991,
#     'lon': -79.379385,
#     'altitude': 0.0,
#     'address': 'Jarvis St / Isabella St',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'is_valet_station': False,
#     'groups': [],
#     'obcn': '416-569-7503',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7032',
#     'name': 'Augusta Ave / Dundas St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652473,
#     'lon': -79.401456,
#     'altitude': 0.0,
#     'address': 'Augusta Ave / Dundas St W',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-622-8139',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7033',
#     'name': 'Union Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645609,
#     'lon': -79.380386,
#     'altitude': 0.0,
#     'address': 'Union Station',
#     'capacity': 43,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-620-1494',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7034',
#     'name': 'Church St / Bloor St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671389,
#     'lon': -79.382919,
#     'altitude': 0.0,
#     'address': 'Church St / Bloor St E',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '437-992-7029',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7035',
#     'name': 'Queen St W / Ossington Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643975,
#     'lon': -79.419576,
#     'altitude': 0.0,
#     'address': 'Queen St W / Ossington Ave',
#     'capacity': 31,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7197-7035'],
#     'obcn': '416-371-6632',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7036',
#     'name': 'Trinity St /Front St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.651318,
#     'lon': -79.36023,
#     'altitude': 0.0,
#     'address': 'Trinity St / Front St E',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-816-5603',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7037',
#     'name': 'Bathurst St / Dundas St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6518918789007,
#     'lon': -79.40577861712723,
#     'altitude': 0.0,
#     'address': 'Bathurst St / Dundas St W',
#     'post_code': 'M5T 2S3',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-621-8042',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7038',
#     'name': 'Dundas St W / Yonge St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656094,
#     'lon': -79.381484,
#     'altitude': 0.0,
#     'address': 'Dundas St W / Yonge St',
#     'capacity': 31,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9714',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7039',
#     'name': 'Simcoe St / Michael Sweet Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652327224103,
#     'lon': -79.3882538196087,
#     'altitude': 0.0,
#     'address': 'Simcoe St / Michael Sweet Ave',
#     'post_code': 'M5T3M3',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-202-6089',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7040',
#     'name': 'Euclid Ave / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.664467,
#     'lon': -79.414783,
#     'altitude': 0.0,
#     'address': 'Euclid Ave / Bloor St W',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-565-9380',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7041',
#     'name': 'Edward St / Yonge St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656729,
#     'lon': -79.382736,
#     'altitude': None,
#     'address': 'Edward St / Yonge St',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9697',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7042',
#     'name': 'Sherbourne St / Wellesley St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6673,
#     'lon': -79.374,
#     'altitude': 0.0,
#     'address': 'Sherbourne St / Wellesley St E',
#     'capacity': 31,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-804-0543',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7043',
#     'name': 'Queens Quay W / Lower Simcoe St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.63951,
#     'lon': -79.383717,
#     'altitude': 0.0,
#     'address': 'Queens Quay W / Lower Simcoe St',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-204-1380',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7044',
#     'name': 'Church St / Alexander St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.663722,
#     'lon': -79.380288,
#     'altitude': 0.0,
#     'address': 'Church St / Alexander St',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-618-1341',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7045',
#     'name': 'Bond St / Queen St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.653236,
#     'lon': -79.376716,
#     'altitude': 0.0,
#     'address': 'Bond St / Queen St E',
#     'capacity': 37,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'is_valet_station': False,
#     'groups': [],
#     'obcn': '647-629-0639',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7046',
#     'name': 'Niagara St / Richmond St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64534,
#     'lon': -79.409597,
#     'altitude': 0.0,
#     'address': 'Niagara St / Richmond St W',
#     'capacity': 42,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7245-7046'],
#     'obcn': '647-643-9655',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7047',
#     'name': 'University Ave / Gerrard St W (East Side)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.657763,
#     'lon': -79.389165,
#     'altitude': 0.0,
#     'address': 'University Ave / Gerrard St W',
#     'capacity': 25,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'is_valet_station': False,
#     'groups': ['P7004-7047'],
#     'obcn': '647-643-9690',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7048',
#     'name': 'Front St W / Yonge St (Hockey Hall of Fame)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.646144,
#     'lon': -79.377962,
#     'altitude': 0.0,
#     'address': 'Front St W / Yonge St (Hockey Hall of Fame)',
#     'capacity': 47,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-204-0984',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7049',
#     'name': 'Portland St / Queen St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6476,
#     'lon': -79.4015,
#     'altitude': 0.0,
#     'address': 'Queen St W / Portland St',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-624-3144',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7050',
#     'name': 'Richmond St E / Jarvis St Green P',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 43.652634,
#     'lon': -79.374222,
#     'altitude': 0.0,
#     'address': 'Richmond St E / Jarvis St Green P',
#     'capacity': 16,
#     'is_charging_station': True,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7458-7050'],
#     'obcn': '416-602-5376',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7052',
#     'name': 'Wellington St W / Bay St',
#     'physical_configuration': 'VAULT',
#     'lat': 43.647259,
#     'lon': -79.379878,
#     'altitude': 0.0,
#     'address': 'Wellington St W / Bay St',
#     'capacity': 55,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-723-3438',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7053',
#     'name': 'Metro Hall Plaza',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645859,
#     'lon': -79.38783,
#     'altitude': None,
#     'address': 'Metro Hall Plaza',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7253-7053'],
#     'obcn': '647-201-7794',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7054',
#     'name': 'Navy Wharf Crt / Bremner Blvd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640722,
#     'lon': -79.391051,
#     'altitude': 0.0,
#     'address': 'Navy Wharf Ct. / Bremner Blvd.',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7054-7073'],
#     'obcn': '416-662-2516',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7055',
#     'name': 'Jarvis St / Carlton St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66207,
#     'lon': -79.37617,
#     'altitude': 0.0,
#     'address': 'Jarvis St / Carlton St',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-722-3901',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7057',
#     'name': 'Simcoe St / Wellington St W South',
#     'physical_configuration': 'VAULT',
#     'lat': 43.6458569,
#     'lon': -79.3853654,
#     'altitude': 0.0,
#     'address': 'Simcoe St / Wellington St 1',
#     'post_code': 'M6a1a1',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-641-2103',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7058',
#     'name': 'Huron St / Harbord St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6637,
#     'lon': -79.400053,
#     'altitude': 0.0,
#     'address': 'Huron/ Harbord St',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9725',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7059',
#     'name': 'Front St W / Blue Jays Way',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643473,
#     'lon': -79.390477,
#     'altitude': 0.0,
#     'address': 'Front St W / Blue Jays Way',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-241-7299',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7061',
#     'name': 'Dalton Rd / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6662942,
#     'lon': -79.4066433,
#     'altitude': 0.0,
#     'address': 'Dalton Rd / Bloor St W',
#     'post_code': 'M6G1A1',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7254-7061'],
#     'obcn': '647-643-9676',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7063',
#     'name': "Queen's Park / Bloor St W",
#     'physical_configuration': 'REGULAR',
#     'lat': 43.668456,
#     'lon': -79.393899,
#     'altitude': 0.0,
#     'address': "Queen's Park / Bloor St W",
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-632-5491',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7064',
#     'name': '51 Parliament St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.65205,
#     'lon': -79.362198,
#     'altitude': 0.0,
#     'address': '51 Parliament St',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-241-9519',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7065',
#     'name': 'Dundas St E / Parliament St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.659575,
#     'lon': -79.365769,
#     'altitude': 0.0,
#     'address': 'Dundas St E / Parliament St',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-568-2679',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7066',
#     'name': 'Willcocks St / St. George St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.662085,
#     'lon': -79.397735,
#     'altitude': 0.0,
#     'address': 'Willcocks St / St. George St',
#     'capacity': 17,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9624',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7068',
#     'name': 'Blantyre Park',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.68306889999999,
#     'lon': -79.279682,
#     'altitude': 0.0,
#     'address': '163 Fallingbrook Rd',
#     'cross_street': 'Kingston/Fallingbrook',
#     'post_code': 'M1N 1N3',
#     'capacity': 22,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '437-999-9028',
#     'nearby_distance': 1609.34,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7069',
#     'name': 'Queen St W / Spadina Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.649147,
#     'lon': -79.395504,
#     'altitude': 0.0,
#     'address': 'Queen St W / Spadina Ave',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7256-7069'],
#     'obcn': '647-622-8344',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7070',
#     'name': '25 York St – Union Station South',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643667,
#     'lon': -79.380414,
#     'altitude': 0.0,
#     'address': '25 York St – Union Station South',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7070-7470'],
#     'obcn': '416-624-8596',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7071',
#     'name': '161 Bleecker St (South of Wellesley)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.666233,
#     'lon': -79.373327,
#     'altitude': 0.0,
#     'address': '161 Bleecker St (South of Wellesley)',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9846',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7072',
#     'name': 'Fleet St / Bathurst St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.636611,
#     'lon': -79.400042,
#     'altitude': 0.0,
#     'address': 'Fleet St / Bathurst St',
#     'post_code': 'M6G1X2',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-564-6690',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7073',
#     'name': 'Spadina Ave / Fort York Blvd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640114,
#     'lon': -79.393249,
#     'altitude': 0.0,
#     'address': 'Spadina Ave / Fort York Blvd',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7054-7073'],
#     'obcn': '416-627-9646',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7074',
#     'name': 'King St E / Church St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.65003919999999,
#     'lon': -79.3733541,
#     'altitude': 0.0,
#     'address': 'St James Park',
#     'post_code': 'M5C 1G6',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9718',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7075',
#     'name': 'Queens Quay W / Dan Leckie Way',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.636533,
#     'lon': -79.395854,
#     'altitude': 0.0,
#     'address': 'Queens Quay W / Dan Leckie Way',
#     'capacity': 26,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-669-9604',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7076',
#     'name': 'York St / Queens Quay W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640132,
#     'lon': -79.380464,
#     'altitude': 0.0,
#     'address': 'York St / Queens Quay W',
#     'capacity': 57,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '416-618-7456',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7077',
#     'name': 'College Park South',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.659777,
#     'lon': -79.382767,
#     'altitude': 0.0,
#     'address': 'College Park South',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9694',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7078',
#     'name': 'College St / Major St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6576,
#     'lon': -79.4032,
#     'altitude': 0.0,
#     'address': 'College St / Major St',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7023-7078'],
#     'obcn': '647-643-9638',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7079',
#     'name': 'McGill St / Church St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.660694,
#     'lon': -79.379052,
#     'altitude': 0.0,
#     'address': 'McGill St / Church St',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7292-7079'],
#     'obcn': '437-999-8524',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7083',
#     'name': 'Danforth Ave / Barrington Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.688325,
#     'lon': -79.300463,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Barrington Ave',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-631-4821',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7084',
#     'name': 'High Park - Grenadier Cafe',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645599,
#     'lon': -79.4657123,
#     'altitude': 0.0,
#     'address': 'High Park - Grenadier Cafe',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7084-7461'],
#     'obcn': '647-643-9563',
#     'nearby_distance': 1609.34,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7085',
#     'name': 'Danforth Ave / Westlake Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.687323,
#     'lon': -79.304848,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Westlake Ave',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-201-8853',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7086',
#     'name': 'High Park - West Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.651922,
#     'lon': -79.465693,
#     'altitude': 0.0,
#     'address': 'High Park - West Rd',
#     'post_code': '1324',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'is_valet_station': False,
#     'groups': [],
#     'obcn': '647-641-7093',
#     'nearby_distance': 1609.34,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7087',
#     'name': 'Danforth Ave / Aldridge Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.684758,
#     'lon': -79.316767,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Aldridge Ave',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7087-7429'],
#     'obcn': '647-641-9873',
#     'nearby_distance': 1000.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7088',
#     'name': 'Danforth Ave / Coxwell Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.683378,
#     'lon': -79.322961,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Coxwell Ave',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-248-5891',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7089',
#     'name': 'Church St  / Wood St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.662712,
#     'lon': -79.379903,
#     'altitude': 102.08,
#     'address': 'Church St / Wood St',
#     'capacity': 18,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-262-1148',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7090',
#     'name': 'Danforth Ave / Lamb Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.681991,
#     'lon': -79.329455,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Lamb Ave',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-641-6203',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7091',
#     'name': 'Donlands Subway Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.681114,
#     'lon': -79.3373885,
#     'altitude': 0.0,
#     'address': 'Donlands Station',
#     'post_code': 'M4J 1P3',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7091-7092'],
#     'obcn': '647-669-1705',
#     'nearby_distance': 1000.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7093',
#     'name': 'Danforth Ave / Gough Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.678401,
#     'lon': -79.346289,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Gough Ave',
#     'capacity': 25,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-669-1671',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7094',
#     'name': '14 Arundel Ave',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 43.6784834,
#     'lon': -79.3513564,
#     'altitude': 0.0,
#     'address': '14 Arundel Ave',
#     'cross_street': 'Arundel Ave - Chester Subway station',
#     'post_code': 'M4K 3A2',
#     'capacity': 25,
#     'is_charging_station': True,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7094-7450'],
#     'obcn': '14 Arundel Ave - EBS - @CP 87',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7095',
#     'name': 'Danforth Ave / Ellerbeck St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.677076,
#     'lon': -79.35667,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Ellerbeck St',
#     'capacity': 14,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-669-1678',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7096',
#     'name': 'Lower Don River Trail and Taylor Creek Trail',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.7027268,
#     'lon': -79.33368089999999,
#     'altitude': 0.0,
#     'address': '425 Don Mills Rd',
#     'post_code': 'M4J',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7287-7096'],
#     'obcn': '647-669-3908',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7097',
#     'name': 'Riverdale Park North (Broadview Ave)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671172,
#     'lon': -79.354704,
#     'altitude': 0.0,
#     'address': 'Riverdale Park North (Broadview Ave)',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-643-9838',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7099',
#     'name': 'Cherry St / Mill St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6513927,
#     'lon': -79.35794659999999,
#     'altitude': 0.0,
#     'address': 'Cherry St / Mill St',
#     'post_code': 'M5A 4T3',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-640-7714',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7100',
#     'name': 'Dundas St E / Regent Park Blvd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.660207,
#     'lon': -79.361275,
#     'altitude': 0.0,
#     'address': 'Dundas St E / Regent Park Blvd',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-669-3847',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7101',
#     'name': 'Lower Sherbourne St / The Esplanade',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.648655,
#     'lon': -79.367061,
#     'altitude': 0.0,
#     'address': 'Lower Sherbourne St / The Esplanade',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-641-5818',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7102',
#     'name': 'Nelson St / Duncan St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.648711,
#     'lon': -79.389728,
#     'altitude': 0.0,
#     'address': 'Nelson St / Duncan St',
#     'capacity': 31,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7017-7102'],
#     'obcn': '647-641-5951',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7103',
#     'name': 'Jimmie Simpson Park (Queen St E)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6605603,
#     'lon': -79.3437663,
#     'altitude': 0.0,
#     'address': 'Jimmie Simpson Park (Queen St E)',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-669-2521',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7104',
#     'name': 'King St E / River St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656784782853144,
#     'lon': -79.35627385059036,
#     'altitude': 0.0,
#     'address': 'King St E / River St',
#     'post_code': 'M5A 1M6',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-641-5813',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7105',
#     'name': 'Queen St E / Sackville St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6561111,
#     'lon': -79.36138888888888,
#     'altitude': 0.0,
#     'address': 'Queen St E / Sackville St',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-290-7069',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7106',
#     'name': 'Mill St / Tannery Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652219,
#     'lon': -79.354455,
#     'altitude': 0.0,
#     'address': 'Mill St / Tannery Rd',
#     'capacity': 27,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-641-5839',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7107',
#     'name': 'Cherry St / Distillery Ln',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650279,
#     'lon': -79.356832,
#     'altitude': 0.0,
#     'address': 'Cherry St / Distillery Ln',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-669-2608',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7108',
#     'name': 'Front St E / Cherry St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652686,
#     'lon': -79.358395,
#     'altitude': 0.0,
#     'address': 'Front St E / Cherry St',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': ['P7493-7108'],
#     'obcn': '647-669-4512',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7109',
#     'name': 'Seaton St / Dundas St E - SMART',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.658777,
#     'lon': -79.369596,
#     'altitude': 0.0,
#     'address': 'Seaton St / Dundas St E',
#     'capacity': 32,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '647-669-3971',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7110',
#     'name': 'Queen St E / Berkeley St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6552778,
#     'lon': -79.36583333333333,
#     'altitude': 0.0,
#     'address': 'Queen St E / Berkeley St',
#     'capacity': 15,
#     'is_charging_station': False,
# ...
#     'obcn': 'Ward 5 - (590 Keele St)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7896',
#     'name': 'Arlington Parkette',
#     'physical_configuration': 'VAULT',
#     'lat': 43.69105005197055,
#     'lon': -79.43281746494293,
#     'altitude': 0.0,
#     'address': '460 Arlington Ave',
#     'cross_street': 'Arlington Ave / Fernandez Ln',
#     'post_code': 'M6C 3A2',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 12- (460 Arlington Ave)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7897',
#     'name': '50 Overlea Blvd',
#     'physical_configuration': 'VAULT',
#     'lat': 43.70735995245773,
#     'lon': -79.3447237544922,
#     'altitude': 0.0,
#     'address': '50 Overlea Blvd',
#     'cross_street': 'Overlea Blvd ',
#     'post_code': 'M4H 1B6',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 15 - (50 Overlea Blvd)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7898',
#     'name': 'University Ave / Gerrard St W - SMART(South)',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.65748153286412,
#     'lon': -79.38921396018827,
#     'altitude': 0.0,
#     'address': '545 University Ave ',
#     'cross_street': 'University Ave / Gerrard St W',
#     'post_code': 'M5G 1X8',
#     'capacity': 16,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 11 - (545 University Ave)',
#     'nearby_distance': 100.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7899',
#     'name': 'Queens Park Cres / College St ',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66018127636866,
#     'lon': -79.39083271520538,
#     'altitude': 0.0,
#     'address': '144 College St ',
#     'cross_street': 'Queens Park Cres W / College St',
#     'post_code': 'M5S 3M2',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 11 - (144 College St )',
#     'nearby_distance': 200.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7900',
#     'name': 'Simcoe St / Elm St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656038841714505,
#     'lon': -79.38970387738495,
#     'altitude': 0.0,
#     'address': 'Simcoe St / Elm St',
#     'post_code': 'M5G 1W7',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 11 - (1001 - 522 University Ave)',
#     'nearby_distance': 100.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7901',
#     'name': 'Bloor St W / Kingsmill Rd',
#     'physical_configuration': 'VAULT',
#     'lat': 43.64927890131737,
#     'lon': -79.50312995581972,
#     'altitude': 0.0,
#     'address': '2836 Bloor St W',
#     'cross_street': 'Bloor St W / Kingsmill Rd',
#     'post_code': 'M8X 1A8',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 3 - (2836 Bloor St W)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7902',
#     'name': 'Gunns Rd / Lavender Creek Trail',
#     'physical_configuration': 'VAULT',
#     'lat': 43.675531973168354,
#     'lon': -79.47199740066374,
#     'altitude': 0.0,
#     'address': 'Gunns Rd / Lavender Creek Trail',
#     'cross_street': 'Gunns Rd / Weston Rd',
#     'post_code': 'M6N 1X5',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 5 - (75 Gunns Rd)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7903',
#     'name': 'St Clair Ave W / Symes Rd',
#     'physical_configuration': 'VAULT',
#     'lat': 43.670042134416704,
#     'lon': -79.4789424818056,
#     'altitude': 0.0,
#     'address': '2236 St Clair Ave W',
#     'cross_street': 'St Clair Ave W / Symes Rd',
#     'post_code': 'M6N 5C1',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 5 - (2236 St Clair Ave W)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7904',
#     'name': 'Palmerston Blvd / Lennox St',
#     'physical_configuration': 'VAULT',
#     'lat': 43.66335070995886,
#     'lon': -79.41312798316125,
#     'altitude': 0.0,
#     'address': '523 Palmerston Blvd',
#     'cross_street': 'Palmerston Blvd / Lennox St',
#     'post_code': 'M6G 2P4',
#     'capacity': 11,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 11 - (523 Palmerston Blvd)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7905',
#     'name': 'Palmerston Blvd / Herrick St',
#     'physical_configuration': 'VAULT',
#     'lat': 43.662155314819906,
#     'lon': -79.412666442599,
#     'altitude': 0.0,
#     'address': '480 Palmerston Blvd',
#     'cross_street': 'Palmerston Blvd / Herrick St',
#     'post_code': 'M6G 2P1',
#     'capacity': 10,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 11 - (480 Palmerston Blvd)',
#     'nearby_distance': 200.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7906',
#     'name': 'Princess St / Front St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650297574961044,
#     'lon': -79.36648460341635,
#     'altitude': 0.0,
#     'address': '201/207 Princess St',
#     'post_code': 'M5A 1E8',
#     'capacity': 14,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 13 - (207 Front St E)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7907',
#     'name': '365 lippincott St',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 43.6649482,
#     'lon': -79.40947,
#     'altitude': 0.0,
#     'address': '365 lippincott St',
#     'cross_street': '365 Lippincott St - South West of Bloor / Bathurst',
#     'post_code': 'M5S 1Y5',
#     'capacity': 40,
#     'is_charging_station': True,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': '365 Lippincott - EBS @ CP 51',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7909',
#     'name': 'E.T Seton Park - South ',
#     'physical_configuration': 'VAULT',
#     'lat': 43.70503461857136,
#     'lon': -79.33547292037659,
#     'altitude': 0.0,
#     'address': 'E.T Seton Park - South ',
#     'cross_street': 'E.T Seton Park South / Lower Don Recreation Trail',
#     'post_code': 'M3C',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'E.T Seton Park South - Area 2',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7910',
#     'name': 'Eglinton Ave E / Brentcliffe Rd',
#     'physical_configuration': 'VAULT',
#     'lat': 43.714305793017544,
#     'lon': -79.36089045040129,
#     'altitude': 0.0,
#     'address': '939 Eglinton Ave E',
#     'cross_street': 'Eglinton Ave E / Brentcliffe Rd',
#     'post_code': 'M4G 4E8',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 15 - (939 Eglinton Ave E )',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7911',
#     'name': 'King St W / York St (2)',
#     'physical_configuration': 'VAULT',
#     'lat': 43.647968822765,
#     'lon': -79.38316961352653,
#     'altitude': 0.0,
#     'address': '59 King St W',
#     'cross_street': 'King St W / York St',
#     'post_code': 'M5H 1A1',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 10 - (59 King St W)',
#     'nearby_distance': 1.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7912',
#     'name': 'Joe Shuster Way / King St W ',
#     'physical_configuration': 'VAULT',
#     'lat': 43.64039672322004,
#     'lon': -79.4237424131447,
#     'altitude': 0.0,
#     'address': '30 Joe Shuster Way',
#     'post_code': 'M6K',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 10 - (30 Joe Shuster Way)',
#     'nearby_distance': 100.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7913',
#     'name': 'St. George St / Willcocks St',
#     'physical_configuration': 'VAULT',
#     'lat': 43.662452744495575,
#     'lon': -79.3978384219513,
#     'altitude': 0.0,
#     'address': 'St George St / Willcocks St',
#     'post_code': 'M5S 3G3',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 11 - (100 St. George St)',
#     'nearby_distance': 100.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7914',
#     'name': 'York St / Wellington St W (2)',
#     'physical_configuration': 'VAULT',
#     'lat': 43.647043061824,
#     'lon': -79.38314120681535,
#     'altitude': 0.0,
#     'address': '100 Wellington St W ',
#     'cross_street': 'York St / Wellington St W',
#     'post_code': 'M5J 2R2',
#     'capacity': 26,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 10 - (100 Wellington St W)',
#     'nearby_distance': 5.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7915',
#     'name': 'Rogers Rd / Watt Ave',
#     'physical_configuration': 'VAULT',
#     'lat': 43.68233679999999,
#     'lon': -79.4680594,
#     'altitude': 0.0,
#     'address': '500 Rogers Rd',
#     'cross_street': 'Rogers Rd / Watt Ave',
#     'post_code': 'M6M 1B3',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 5 - (500 Rogers Rd)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7916',
#     'name': 'University Ave / Pearl St ',
#     'physical_configuration': 'VAULT',
#     'lat': 43.64843020000001,
#     'lon': -79.38556559999999,
#     'altitude': 0.0,
#     'address': 'University Ave / Pearl St ',
#     'post_code': 'M5H 1L2',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 10 - (118 Pearl St)',
#     'nearby_distance': 100.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7917',
#     'name': 'King St W / University Ave',
#     'physical_configuration': 'VAULT',
#     'lat': 43.64781808540915,
#     'lon': -79.38427999073791,
#     'altitude': 0.0,
#     'address': '150 King St W',
#     'post_code': 'M5H 1J9',
#     'capacity': 18,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 10 - (150 King St W)',
#     'nearby_distance': 50.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7918',
#     'name': 'Albion Rd/ Arcot Blvd',
#     'physical_configuration': 'VAULT',
#     'lat': 43.727621709316395,
#     'lon': -79.55254902939286,
#     'altitude': 0.0,
#     'address': 'Albion Rd/ Arcot Blvd (Summerlea Park)',
#     'post_code': 'M9W',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 1 - (2 Arcot Blvd - Summerlea Park)',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7919',
#     'name': 'Armel Ct / Albion Rd',
#     'physical_configuration': 'VAULT',
#     'lat': 43.721532966873205,
#     'lon': -79.5455834809678,
#     'altitude': 0.0,
#     'address': 'Armel Ct / Albion Rd',
#     'post_code': 'M9W 6L4',
#     'capacity': 18,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 1 - ( 2 Armel Ct)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7920',
#     'name': '75 Tandridge Cres',
#     'physical_configuration': 'VAULT',
#     'lat': 43.729578273586064,
#     'lon': -79.54699793872719,
#     'altitude': 0.0,
#     'address': '75 Tandridge Cres',
#     'cross_street': 'Tandridge Cres / Arcot Blvd',
#     'post_code': 'M9W 2N9',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 1 - (75 Tandridge Cres)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7921',
#     'name': 'Islington Ave / Finch Ave W',
#     'physical_configuration': 'VAULT',
#     'lat': 43.74445257991756,
#     'lon': -79.56824985721664,
#     'altitude': 0.0,
#     'address': '2765 Islington Ave ',
#     'post_code': 'M9V 2R2',
#     'capacity': 15,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 1 - (2765 Islington Ave)',
#     'nearby_distance': 300.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7922',
#     'name': '35 Erindale Ave',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 43.67729,
#     'lon': -79.35741,
#     'altitude': 0.0,
#     'address': '35 Erindale Ave',
#     'post_code': 'M4K 1R9',
#     'capacity': 23,
#     'is_charging_station': True,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 13 - (35 Erindale Ave@CP 78)',
#     'nearby_distance': 100.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7923',
#     'name': 'Trethewey Dr / Jane St',
#     'physical_configuration': 'VAULT',
#     'lat': 43.697417070558615,
#     'lon': -79.50079830912324,
#     'altitude': 0.0,
#     'address': '725 Trethewey Dr ',
#     'cross_street': 'Trethewey Dr / Jane St',
#     'post_code': 'M6M 5J7',
#     'capacity': 19,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 5 - (725 Trethewey Dr)',
#     'nearby_distance': 500.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7924',
#     'name': 'Duncan St / Adelaide St W - SMART',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.64809661123633,
#     'lon': -79.38864543439331,
#     'altitude': 0.0,
#     'address': '19 Duncan St ',
#     'cross_street': 'Duncan St / Adelaide St W',
#     'post_code': 'M5H 3G6',
#     'capacity': 12,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 10 - (19 Duncan St)',
#     'nearby_distance': 350.0,
#     '_ride_code_support': True,
#     'rental_uris': {}},
#    {'station_id': '7925',
#     'name': 'Niagara St / King St W - SMART',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.64286370000001,
#     'lon': -79.40713060000002,
#     'altitude': 0.0,
#     'address': '801 King St W ',
#     'cross_street': 'Niagara St / King St W',
#     'post_code': 'M5V 3C9',
#     'capacity': 23,
#     'is_charging_station': False,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': [],
#     'obcn': 'Ward 10 - (801 King St W)',
#     'nearby_distance': 350.0,
#     '_ride_code_support': True,
#     'rental_uris': {}}]}}

# %%
r = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information')

df_bike_stations = pd.DataFrame(json.loads(r.content)['data']['stations'])[['station_id', 'name', 'lat', 'lon']].astype({
                            'station_id': 'string', 
                            'name': 'string'
                            })

df_bike_stations.head() # Visualize
# Out:
#   station_id                          name        lat        lon
# 0       7000  Fort York  Blvd / Capreol Ct  43.639832 -79.395954
# 1       7001     Wellesley Station Green P  43.664964 -79.383550
# 2       7002    St. George St / Bloor St W  43.667333 -79.399429
# 3       7003      Madison Ave / Bloor St W  43.667158 -79.402761
# 4       7005           King St W / York St  43.648001 -79.383177

# %%
# Rename column name
df_bike_stations = df_bike_stations.rename(columns={'name':"station_name"})
    # name to station_name

df_bike_stations.info()

df_bike_stations['station_id'].sort_values(ascending= False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785 entries, 0 to 784
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_id    785 non-null    string
#  1   station_name  785 non-null    string
#  2   lat           785 non-null    float64
#  3   lon           785 non-null    float64
# dtypes: float64(2), string(2)
# memory usage: 24.7 KB
# 784    7925
# 783    7924
# 782    7923
# 781    7922
# 780    7921
#        ...
# 4      7005
# 3      7003
# 2      7002
# 1      7001
# 0      7000
# Name: station_id, Length: 785, dtype: string

# %% [markdown]
# ---

# %% [markdown]
# ### Pricing Plans

# %%
# Visualize Station Dataset

r = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_pricing_plans').json()

r
# Out:
# {'last_updated': 1706414230,
#  'ttl': 40,
#  'data': {'plans': [{'plan_id': '186',
#     'name': 'Annual 30',
#     'currency': 'CAD',
#     'price': 105.0,
#     'description': 'Unlimited 30-min trips on classic bikes',
#     'is_taxable': 1},
#    {'plan_id': '191',
#     'name': 'CMP-City of Toronto',
#     'currency': 'CAD',
#     'price': 90.0,
#     'description': 'CMP-City of Toronto',
#     'is_taxable': 1},
#    {'plan_id': '208',
#     'name': 'Annual 45',
#     'currency': 'CAD',
#     'price': 120.0,
#     'description': 'Unlimited 45-min trips on classic bikes',
#     'is_taxable': 1},
#    {'plan_id': '209',
#     'name': 'Corporate 30',
#     'currency': 'CAD',
#     'price': 84.0,
#     'description': 'Corporate 30',
#     'is_taxable': 1},
#    {'plan_id': '210',
#     'name': 'Corporate 45',
#     'currency': 'CAD',
#     'price': 96.0,
#     'description': 'Corporate 45',
#     'is_taxable': 1},
#    {'plan_id': '211',
#     'name': 'OPTION 2 TEST',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '212',
#     'name': 'CMP-MROC30',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '213',
#     'name': 'CMP-MROC45',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': 'CMP-MROC45',
#     'is_taxable': 1},
#    {'plan_id': '214',
#     'name': 'CMP-PPCMP45',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '215',
#     'name': 'CMP-PPCMP30',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '216',
#     'name': 'CMP CoT30',
#     'currency': 'CAD',
#     'price': 63.0,
#     'description': 'CMP CoT30',
#     'is_taxable': 1},
#    {'plan_id': '217',
#     'name': 'CMP CoT45',
#     'currency': 'CAD',
#     'price': 72.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '218',
#     'name': 'CMP-Smart30',
#     'currency': 'CAD',
#     'price': 78.75,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '219',
#     'name': 'CMP-Smart45',
#     'currency': 'CAD',
#     'price': 90.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '220',
#     'name': 'CMP AnimalClinic30',
#     'currency': 'CAD',
#     'price': 52.5,
#     'description': 'CMP AnimalClinic30',
#     'is_taxable': 1},
#    {'plan_id': '221',
#     'name': 'CMP AnimalClinic45',
#     'currency': 'CAD',
#     'price': 63.0,
#     'description': 'CMP AnimalClinic45',
#     'is_taxable': 1},
#    {'plan_id': '222',
#     'name': 'CMP-ParkPeople30',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': 'CMP-ParkPeople30',
#     'is_taxable': 1},
#    {'plan_id': '223',
#     'name': 'CMP-ParkPeople45',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': 'CMP-ParkPeople45',
#     'is_taxable': 1},
#    {'plan_id': '224',
#     'name': 'VIP Trial',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': 'VIP Trial',
#     'is_taxable': 1},
#    {'plan_id': '225',
#     'name': 'CMP-TP30',
#     'currency': 'CAD',
#     'price': 63.0,
#     'description': 'CMP-TP30',
#     'is_taxable': 1},
#    {'plan_id': '226',
#     'name': 'CMP-TP45',
#     'currency': 'CAD',
#     'price': 72.0,
#     'description': 'CMP-TP45',
#     'is_taxable': 1},
#    {'plan_id': '227',
#     'name': 'CMP-MUR30',
#     'currency': 'CAD',
#     'price': 31.5,
#     'description': 'CMP-MUR30',
#     'is_taxable': 1},
#    {'plan_id': '228',
#     'name': 'CMP-MUR45',
#     'currency': 'CAD',
#     'price': 36.0,
#     'description': 'CMP-MUR45',
#     'is_taxable': 1},
#    {'plan_id': '229',
#     'name': 'CMP-GP30',
#     'currency': 'CAD',
#     'price': 49.5,
#     'description': 'CMP-GP30',
#     'is_taxable': 1},
#    {'plan_id': '230',
#     'name': 'CMP-GP45',
#     'currency': 'CAD',
#     'price': 57.5,
#     'description': 'CMP-GP45',
#     'is_taxable': 1},
#    {'plan_id': '231',
#     'name': 'CMP-LEA30',
#     'currency': 'CAD',
#     'price': 63.0,
#     'description': 'CMP-LEA30',
#     'is_taxable': 1},
#    {'plan_id': '232',
#     'name': 'CMP-LEA45',
#     'currency': 'CAD',
#     'price': 72.0,
#     'description': 'CMP-LEA45',
#     'is_taxable': 1},
#    {'plan_id': '233',
#     'name': 'CMP-SMH30',
#     'currency': 'CAD',
#     'price': 31.5,
#     'description': 'CMP-SMH30',
#     'is_taxable': 1},
#    {'plan_id': '234',
#     'name': 'CMP-SMH45',
#     'currency': 'CAD',
#     'price': 36.0,
#     'description': 'CMP-SMH45',
#     'is_taxable': 1},
#    {'plan_id': '235',
#     'name': 'CMP-PLUS30',
#     'currency': 'CAD',
#     'price': 63.0,
#     'description': 'CMP-PLUS30',
#     'is_taxable': 1},
#    {'plan_id': '236',
#     'name': 'CMP-PLUS45',
#     'currency': 'CAD',
#     'price': 72.0,
#     'description': 'CMP-PLUS45',
#     'is_taxable': 1},
#    {'plan_id': '244',
#     'name': 'CMP-SmartDen30',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': 'CMP-SmartDen30',
#     'is_taxable': 1},
#    {'plan_id': '245',
#     'name': 'CMP-SmartDen45',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': 'CMP-SmartDen45',
#     'is_taxable': 1},
#    {'plan_id': '248',
#     'name': 'CMP-DewartGleason45',
#     'currency': 'CAD',
#     'price': 63.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '249',
#     'name': 'CMP-DewartGleason30',
#     'currency': 'CAD',
#     'price': 52.5,
#     'description': 'CMP-DewartGleason30',
#     'is_taxable': 1},
#    {'plan_id': '251',
#     'name': 'Classic Bike DayPass',
#     'currency': 'CAD',
#     'price': 15.0,
#     'description': '90 min rides on classic bikes',
#     'is_taxable': 1},
#    {'plan_id': '252',
#     'name': 'Pay-As-You-Go ($1 Unlock Fee)',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': '+Classic bike $0.12/min; Ebike $0.20/min  ',
#     'is_taxable': 1},
#    {'plan_id': '254',
#     'name': 'CMP-CollabArc30',
#     'currency': 'CAD',
#     'price': 42.0,
#     'description': 'CMP-CollabArc30',
#     'is_taxable': 1},
#    {'plan_id': '255',
#     'name': 'CMP-CollabArc45',
#     'currency': 'CAD',
#     'price': 48.0,
#     'description': 'CMP-CollabArc45',
#     'is_taxable': 1},
#    {'plan_id': '256',
#     'name': 'CMP-GPP45 (test)',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': '',
#     'is_taxable': 1},
#    {'plan_id': '257',
#     'name': 'CMP-GreenP45',
#     'currency': 'CAD',
#     'price': 0.0,
#     'description': 'CMP-GreenP45',
#     'is_taxable': 1},
#    {'plan_id': '258',
#     'name': 'Annual 30 - ODSP',
#     'currency': 'CAD',
#     'price': 105.0,
#     'description': 'Unlimited 30-min trips with any bike',
#     'is_taxable': 1},
#    {'plan_id': '259',
#     'name': 'Annual 45 - ODSP',
#     'currency': 'CAD',
#     'price': 120.0,
#     'description': 'Unlimited 45-min trips with any bike',
#     'is_taxable': 1},
#    {'plan_id': '260',
#     'name': 'CMP-GCC 30',
#     'currency': 'CAD',
#     'price': 63.0,
#     'description': 'CMP-GCC 30',
#     'is_taxable': 1},
#    {'plan_id': '261',
#     'name': 'CMP-GCC 45',
#     'currency': 'CAD',
#     'price': 72.0,
#     'description': 'CMP-GCC 45',
#     'is_taxable': 1},
#    {'plan_id': '262',
#     'name': 'CMP-BeyondTech30',
#     'currency': 'CAD',
#     'price': 31.5,
#     'description': 'CMP-BeyondTech30',
#     'is_taxable': 1},
#    {'plan_id': '263',
#     'name': 'CMP-BeyondTech45',
#     'currency': 'CAD',
#     'price': 36.0,
#     'description': 'CMP-BeyondTech45',
#     'is_taxable': 1},
#    {'plan_id': '264',
#     'name': 'Annual 30 3 Install',
#     'currency': 'CAD',
#     'price': 105.0,
#     'description': '3 monthly installments of $35 + tax',
#     'is_taxable': 1},
#    {'plan_id': '265',
#     'name': 'Annual 45 3 Install',
#     'currency': 'CAD',
#     'price': 120.0,
#     'description': '3 monthly installments of $40 + tax',
#     'is_taxable': 1}]}}

# %%
r = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/system_pricing_plans')

df_bike_priceplans = pd.DataFrame(json.loads(r.content)['data']['plans']).astype({
                    'plan_id': 'string', 
                    'name': 'string',
                    'currency': 'string',
                    'currency': 'string',
                    'description': 'string'
                    })

df_bike_priceplans.head()
# Out:
#   plan_id                 name currency  price  \
# 0     186            Annual 30      CAD  105.0
# 1     191  CMP-City of Toronto      CAD   90.0
# 2     208            Annual 45      CAD  120.0
# 3     209         Corporate 30      CAD   84.0
# 4     210         Corporate 45      CAD   96.0
#
#                                description  is_taxable
# 0  Unlimited 30-min trips on classic bikes           1
# 1                      CMP-City of Toronto           1
# 2  Unlimited 45-min trips on classic bikes           1
# 3                             Corporate 30           1
# 4                             Corporate 45           1

# %%
df_bike_priceplans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   plan_id      49 non-null     string
#  1   name         49 non-null     string
#  2   currency     49 non-null     string
#  3   price        49 non-null     float64
#  4   description  49 non-null     string
#  5   is_taxable   49 non-null     int64
# dtypes: float64(1), int64(1), string(4)
# memory usage: 2.4 KB

# %% [markdown]
# #### Export Station and Price Plans Data

# %% [markdown]
# I will export and work with these datasets in future workbooks. Below I will import ridership data across various years and combine them into one dataframe.

# %% [markdown]
# *Stations*

# %%
# Stations
df_bike_stations.to_csv("data/bike_stations_raw.csv", index = False) # don't include index as a separate column)

# Price Plans
df_bike_priceplans.to_csv("data/bike_priceplans_raw.csv", index = False)

# %% [markdown]
# ---

# %% [markdown]
# ## Import Ridership Data

# %% [markdown]
# The Bike Share Toronto data is publicly available at the link below: </br>
# https://open.toronto.ca/dataset/bike-share-toronto-ridership-data/ </br>
# </br>
# I have obtained 5 years of the most recent data (2019 - 2023), and saved them by year. The data files were not consistently named so I have imported them by year. After an iteration of importing the data, I realized the datatypes were inconsistent upon import so I have defined the preferred datatypes below.

# %%
#Define temporary dataframes to help with imports
df_temp_1 = pd.DataFrame()
df_temp_2 = pd.DataFrame()
df_temp_3 = pd.DataFrame()
df_temp_4 = pd.DataFrame()
df_temp_5 = pd.DataFrame()
df_temp_6 = pd.DataFrame()
df_temp_7 = pd.DataFrame()
df_temp_8 = pd.DataFrame()
df_temp_9 = pd.DataFrame()
df_temp_10 = pd.DataFrame()
df_temp_11 = pd.DataFrame()
df_temp_12 = pd.DataFrame()

# %%
#Define dtype
dtype_dictionary = {"Trip Id": 'string', 
                    "Trip  Duration": 'Int64',
                    "Start Station Id": 'string', 
                    "Start Time": 'string', #use parse_dates in pd.read_csv()
                    "Start Station Name": 'string',
                    "End Station Id": 'string',
                    "End Time": 'string', #use parse_dates in pd.read_csv()
                    "End Station Name": 'string',
                    "Bike Id": 'string',
                    "User Type": 'string'
                   }

list_parse_date = ["Start Time", "End Time"]

# %% [markdown]
# #### 2019

# %%
df_temp_1 = pd.read_csv("data/2019/2019-Q1.csv", 
                        dtype=dtype_dictionary, parse_dates=list_parse_date)
df_temp_2 = pd.read_csv("data/2019/2019-Q2.csv", 
                        dtype=dtype_dictionary, parse_dates=list_parse_date)
df_temp_3 = pd.read_csv("data/2019/2019-Q3.csv", 
                        dtype=dtype_dictionary, parse_dates=list_parse_date)
df_temp_4 = pd.read_csv("data/2019/2019-Q4.csv",
                        dtype=dtype_dictionary, parse_dates=list_parse_date)

temp_dfs_4 = [df_temp_1, df_temp_2, df_temp_3, df_temp_4]
df_2019 = pd.concat(temp_dfs_4) #Combine into dataframe for the year

# %%
df_2019.head() #visualize
# Out:
#    Trip Id  Trip  Duration Start Station Id          Start Time  \
# 0  4581278            1547             7021 2019-01-01 00:08:00
# 1  4581279            1112             7160 2019-01-01 00:10:00
# 2  4581280             589             7055 2019-01-01 00:15:00
# 3  4581281             259             7012 2019-01-01 00:16:00
# 4  4581282             281             7041 2019-01-01 00:19:00
#
#                         Start Station Name End Station Id            End Time  \
# 0                       Bay St / Albert St           7233 2019-01-01 00:33:00
# 1                 King St W / Tecumseth St           7051 2019-01-01 00:29:00
# 2                   Jarvis St / Carlton St           7013 2019-01-01 00:25:00
# 3  Elizabeth St / Edward St (Bus Terminal)           7235 2019-01-01 00:20:00
# 4                     Edward St / Yonge St           7257 2019-01-01 00:24:00
#
#                           End Station Name Bike Id      User Type
# 0                 King / Cowan Ave - SMART    1296  Annual Member
# 1      Wellesley St E / Yonge St (Green P)    2947  Annual Member
# 2                 Scott St / The Esplanade    2293  Annual Member
# 3  Bay St / College St (West Side) - SMART     283  Annual Member
# 4             Dundas St W / St. Patrick St    1799  Annual Member

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2439517 entries, 0 to 468415
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          datetime64[ns]
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            datetime64[ns]
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), datetime64[ns](2), string(7)
# memory usage: 207.1 MB

# %% [markdown]
# #### 2020 Onwards

# %% [markdown]
# I've decided to build a function to help streamline the upload as the data is broken up by month instead of quarter.

# %%
def upload_helper(list_temp_dfs, int_m, str_y, str_fn_p):
    
    # Doc String for function
    """
    This function is to help with the upload of data files into a list of dataframes.
    
    Specifically, the data folder would be 'data/{year}/{filenameprefix}{month}'
        Where:
            {year} is the year in yyyy format (i.e 2020)
            {month} is the month in MM format (i.e. 01 for January)
            {filenameprefix} is the filename without the {month} variable
    """
    
    
    #Code
    for i in range(len(list_temp_dfs)):
        
        int_m += 1 #increase month value by 1 (starts at 1, ends at 12)
        
        str_m = str(int_m).zfill(2) #converts month integer into 2 character strings (i.e. int 1 = '01')
        
        str_filepath = "data/"+str_y+"/"+str_fn_p+str_m+".csv" #combine filepath

        temp_dfs_12[i] = pd.read_csv(str_filepath, 
                                     dtype=dtype_dictionary, parse_dates=list_parse_date) #load data into list of dataframes

# %%
# Show Doc String
help(upload_helper)
# Out:
# Help on function upload_helper in module __main__:
#
# upload_helper(list_temp_dfs, int_m, str_y, str_fn_p)
#     This function is to help with the upload of data files into a list of dataframes.
#
#     Specifically, the data folder would be 'data/{year}/{filenameprefix}{month}'
#         Where:
#             {year} is the year in yyyy format (i.e 2020)
#             {month} is the month in MM format (i.e. 01 for January)
#             {filenameprefix} is the filename without the {month} variable

# %%
# Create a list of Dataframes
temp_dfs_12 = [df_temp_1, df_temp_2, df_temp_3, df_temp_4, df_temp_5, 
               df_temp_6, df_temp_7, df_temp_8, df_temp_9, df_temp_10, df_temp_11, df_temp_12]

# %% [markdown]
# #### 2020

# %%
# Inputs for the function
str_year = "2020"
str_filename_prefix = "2020-"
int_month = 0

# Upload Helper function (defined above)
upload_helper(list_temp_dfs=temp_dfs_12, 
              int_m= int_month, 
              str_y=str_year, 
              str_fn_p=str_filename_prefix)

df_2020 = pd.concat(temp_dfs_12) #Combine into dataframe for the year

# %%
df_2020.head() #visualize
# Out:
#    Trip Id  Trip  Duration Start Station Id           Start Time  \
# 0  7334128             648             7003  2020-01-01 00:08:00
# 1  7334129             419             7007  2020-01-01 00:10:00
# 2  7334130             566             7113  2020-01-01 00:13:00
# 3  7334131            1274             7333  2020-01-01 00:17:00
# 4  7334132             906             7009  2020-01-01 00:19:00
#
#              Start Station Name End Station Id             End Time  \
# 0      Madison Ave / Bloor St W           7271  2020-01-01 00:19:00
# 1         College St / Huron St           7163  2020-01-01 00:17:00
# 2  Parliament St / Aberdeen Ave           7108  2020-01-01 00:22:00
# 3       King St E / Victoria St           7311  2020-01-01 00:38:00
# 4         King St E / Jarvis St           7004  2020-01-01 00:34:00
#
#                   End Station Name Bike Id      User Type
# 0  Yonge St / Alexander St - SMART    3104  Annual Member
# 1               Yonge St / Wood St    2126  Annual Member
# 2           Front St E / Cherry St    4425  Annual Member
# 3      Sherbourne St / Isabella St    4233  Annual Member
# 4          University Ave / Elm St    2341  Casual Member

# %% [markdown]
# #### 2021

# %% [markdown]
# The January and May 2021 data would return the following error: </br>
# *UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 40656: invalid start byte* </br>
# </br>
# I decided to upload them without the function to deal with the csv encoding of those two files.

# %%
##### Import Data for all months in 2021 except for January and May

# %%
    #Skip January
temp_dfs_12[1] = pd.read_csv("data/2021/Bike share ridership 2021-02.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[2] = pd.read_csv("data/2021/Bike share ridership 2021-03.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[3] = pd.read_csv("data/2021/Bike share ridership 2021-04.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
    #Skip May
temp_dfs_12[5] = pd.read_csv("data/2021/Bike share ridership 2021-06.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[6] = pd.read_csv("data/2021/Bike share ridership 2021-07.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[7] = pd.read_csv("data/2021/Bike share ridership 2021-08.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[8] = pd.read_csv("data/2021/Bike share ridership 2021-09.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[9] = pd.read_csv("data/2021/Bike share ridership 2021-10.csv",
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[10] = pd.read_csv("data/2021/Bike share ridership 2021-11.csv",
                              dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[11] = pd.read_csv("data/2021/Bike share ridership 2021-12.csv",
                              dtype=dtype_dictionary, parse_dates=list_parse_date)

# %%
##### Import Data for January 2021 and May 2021

# %%
# Run file details to see encoding of csv file - Jan
with open("data/2021/Bike share ridership 2021-01.csv") as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='data/2021/Bike share ridership 2021-01.csv' mode='r' encoding='cp1252'>

# %%
# Run file details to see encoding of csv file - May
with open("data/2021/Bike share ridership 2021-05.csv") as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='data/2021/Bike share ridership 2021-05.csv' mode='r' encoding='cp1252'>

# %%
# Import with updated encoding
temp_dfs_12[0] = pd.read_csv("data/2021/Bike share ridership 2021-01.csv", encoding='cp1252',
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[4] = pd.read_csv("data/2021/Bike share ridership 2021-05.csv", encoding='cp1252',
                             dtype=dtype_dictionary, parse_dates=list_parse_date)

# %%
df_2021 = pd.concat(temp_dfs_12) #Combine into dataframe for the year

# %%
df_2021.head() #Visualize
# Out:
#     Trip Id  Trip  Duration Start Station Id          Start Time  \
# 0  10644218            1315             7021 2021-01-01 00:04:00
# 1  10644220             396             7534 2021-01-01 00:07:00
# 2  10644221              86             7162 2021-01-01 00:10:00
# 3  10644222             741             7003 2021-01-01 00:10:00
# 4  10644223            2073             7562 2021-01-01 00:11:00
#
#                      Start Station Name End Station Id            End Time  \
# 0                    Bay St / Albert St           7164 2021-01-01 00:26:00
# 1               Walnut Ave / Queen St W           7524 2021-01-01 00:13:00
# 2              Hayter St / Laplante Ave           7006 2021-01-01 00:11:00
# 3              Madison Ave / Bloor St W           7272 2021-01-01 00:22:00
# 4  Priscilla  Ave / Dundas St W - SMART           7562 2021-01-01 00:45:00
#
#                            End Station Name Bike Id      User Type
# 0  Gould St / Yonge St (Ryerson University)    6795  Annual Member
# 1                               Lisgar Park    4176  Casual Member
# 2           Bay St / College St (East Side)    1814  Annual Member
# 3           Yonge St / Dundonald St - SMART     198  Casual Member
# 4      Priscilla  Ave / Dundas St W - SMART    6688  Casual Member

# %% [markdown]
# #### 2022

# %%
# Inputs for the function
str_year = "2022"
str_filename_prefix = "Bike share ridership 2022-"
int_month = 0

# Upload Helper function (defined above)
upload_helper(list_temp_dfs=temp_dfs_12, 
              int_m= int_month, 
              str_y=str_year, 
              str_fn_p=str_filename_prefix)

df_2022 = pd.concat(temp_dfs_12) #Combine into dataframe for the year

# %%
df_2022.head() #Visualize
# Out:
#     Trip Id  Trip  Duration Start Station Id          Start Time  \
# 0  14805109            4335             7334 2022-01-01 00:02:00
# 1  14805110             126             7443 2022-01-01 00:02:00
# 2  14805112             942             7399 2022-01-01 00:04:00
# 3  14805113            4256             7334 2022-01-01 00:04:00
# 4  14805114            4353             7334 2022-01-01 00:05:00
#
#                 Start Station Name End Station Id            End Time  \
# 0  Simcoe St / Wellington St North           7269 2022-01-01 01:15:00
# 1          Dundas St E / George St           7270 2022-01-01 00:05:00
# 2     Lower Jarvis / Queens Quay E           7686 2022-01-01 00:19:00
# 3  Simcoe St / Wellington St North           7269 2022-01-01 01:15:00
# 4  Simcoe St / Wellington St North           7038 2022-01-01 01:17:00
#
#                   End Station Name Bike Id      User Type
# 0  Toronto Eaton Centre (Yonge St)    5139  Casual Member
# 1  Church St / Dundas St E - SMART    3992  Annual Member
# 2                             <NA>     361  Annual Member
# 3  Toronto Eaton Centre (Yonge St)    4350  Casual Member
# 4           Dundas St W / Yonge St    5074  Casual Member

# %% [markdown]
# #### 2023

# %% [markdown]
# The April 2023 onwards data would return the following error: </br>
# *UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 40656: invalid start byte* </br>
# </br>
# I decided to upload them without the function to deal with the csv encoding of these files.

# %%
# Files without encoding issues
temp_dfs_12[0] = pd.read_csv("data/2023/Bike share ridership 2023-01.csv", 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[1] = pd.read_csv("data/2023/Bike share ridership 2023-02.csv", 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[2] = pd.read_csv("data/2023/Bike share ridership 2023-03.csv", 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)

# %%
# Files WITH encoding issues
temp_dfs_12[3] = pd.read_csv("data/2023/Bike share ridership 2023-04.csv", encoding='cp1252', 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[4] = pd.read_csv("data/2023/Bike share ridership 2023-05.csv", encoding='cp1252', 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[5] = pd.read_csv("data/2023/Bike share ridership 2023-06.csv", encoding='cp1252', 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[6] = pd.read_csv("data/2023/Bike share ridership 2023-07.csv", encoding='cp1252', 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[7] = pd.read_csv("data/2023/Bike share ridership 2023-08.csv", encoding='cp1252', 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[8] = pd.read_csv("data/2023/Bike share ridership 2023-09.csv", encoding='cp1252', 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[9] = pd.read_csv("data/2023/Bike share ridership 2023-10.csv", encoding='cp1252', 
                             dtype=dtype_dictionary, parse_dates=list_parse_date)
temp_dfs_12[10] = pd.read_csv("data/2023/Bike share ridership 2023-11.csv", encoding='cp1252', 
                              dtype=dtype_dictionary, parse_dates=list_parse_date)

# %%
# December File required different encoding for import
temp_dfs_12[11] = pd.read_csv("data/2023/Bike share ridership 2023-12.csv", encoding='utf-8-sig', 
                              dtype=dtype_dictionary, parse_dates=list_parse_date)

# %%
df_2023 = pd.concat(temp_dfs_12) #Combine into dataframe for the year

# %%
df_2023.head() #Visualize
# Out:
#     Trip Id  Trip  Duration Start Station Id          Start Time  \
# 0  20148784             840             7022 2023-01-01 00:00:00
# 1  20148785             722             7399 2023-01-01 00:01:00
# 2  20148786            1054             7269 2023-01-01 00:02:00
# 3  20148790            1329             7721 2023-01-01 00:04:00
# 4  20148791            1291             7721 2023-01-01 00:04:00
#
#                 Start Station Name End Station Id            End Time  \
# 0           Simcoe St / Queen St W           7703 2023-01-01 00:14:00
# 1     Lower Jarvis / Queens Quay E           7533 2023-01-01 00:13:00
# 2  Toronto Eaton Centre (Yonge St)           7076 2023-01-01 00:20:00
# 3                             <NA>           7685 2023-01-01 00:26:00
# 4                             <NA>           7685 2023-01-01 00:26:00
#
#              End Station Name Bike Id      User Type
# 0                        <NA>    1770  Casual Member
# 1  Housey St / Dan Leckie Way    6400  Casual Member
# 2     York St / Queens Quay W    4068  Annual Member
# 3                        <NA>     427  Casual Member
# 4                        <NA>    1840  Casual Member

# %%
for i in range (0,12):
    print(temp_dfs_12[i].columns)
# Out:
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')
# Index(['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time',
#        'Start Station Name', 'End Station Id', 'End Time', 'End Station Name',
#        'Bike Id', 'User Type'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### Individual Year Data Checks - Prior to Combining into one Dataframe

# %% [markdown]
# #### 2019 - Data Inspection

# %%
df_2019.shape # get shape of dataframe (rows, columns)
# Out:
# (2439517, 10)

# %%
df_2019.info() # get info on dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2439517 entries, 0 to 468415
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          datetime64[ns]
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            datetime64[ns]
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), datetime64[ns](2), string(7)
# memory usage: 207.1 MB

# %%
df_2019.isna().sum()  # high-level visualization of null values by column
# Out:
# Trip Id                 0
# Trip  Duration         16
# Start Station Id        0
# Start Time              0
# Start Station Name      0
# End Station Id        454
# End Time                0
# End Station Name      454
# Bike Id                 0
# User Type               0
# dtype: int64

# %% [markdown]
# #### 2020 - Data Inspection

# %%
df_2020.shape # get shape of dataframe (rows, columns)
# Out:
# (2911308, 10)

# %%
df_2020.info() # get info on dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2911308 entries, 0 to 95347
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          object
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            object
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), object(2), string(7)
# memory usage: 247.1+ MB

# %%
df_2020.isna().sum()  # high-level visualization of null values by column
# Out:
# Trip Id                  0
# Trip  Duration           0
# Start Station Id         0
# Start Time               0
# Start Station Name     793
# End Station Id        1301
# End Time                 0
# End Station Name      2049
# Bike Id                 73
# User Type              249
# dtype: int64

# %% [markdown]
# #### 2021 - Data Inspection

# %%
df_2021.shape
# Out:
# (3575182, 10)

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3575182 entries, 0 to 145848
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          datetime64[ns]
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            datetime64[ns]
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), datetime64[ns](2), string(7)
# memory usage: 303.5 MB

# %%
df_2021.isna().sum()
# Out:
# Trip Id                  0
# Trip  Duration           0
# Start Station Id         0
# Start Time               0
# Start Station Name    3680
# End Station Id        1969
# End Time                 0
# End Station Name      5894
# Bike Id                203
# User Type                0
# dtype: int64

# %% [markdown]
# #### 2022 - Data Inspection

# %%
df_2022.shape
# Out:
# (4620469, 10)

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4620469 entries, 0 to 180009
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          datetime64[ns]
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            datetime64[ns]
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), datetime64[ns](2), string(7)
# memory usage: 392.2 MB

# %%
df_2022.isna().sum()
# Out:
# Trip Id                    0
# Trip  Duration             0
# Start Station Id           0
# Start Time                 0
# Start Station Name    183466
# End Station Id          1279
# End Time                   0
# End Station Name      184966
# Bike Id                    0
# User Type                  0
# dtype: int64

# %% [markdown]
# #### 2023 - Data Inspection

# %%
df_2023.shape
# Out:
# (5713141, 10)

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5713141 entries, 0 to 257114
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          datetime64[ns]
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            datetime64[ns]
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), datetime64[ns](2), string(7)
# memory usage: 484.9 MB

# %%
df_2023.isna().sum()
# Out:
# Trip Id                    0
# Trip  Duration             0
# Start Station Id           0
# Start Time                 0
# Start Station Name    595075
# End Station Id          2944
# End Time                   0
# End Station Name      598563
# Bike Id                    0
# User Type                  0
# dtype: int64

# %% [markdown]
# ##### Findings:
# - Datatypes were imported as expected
# - Missing data exist in these dataframes. To investigate as a whole after combining data into one dataframe.
# - In 2020, Start Time and End Time are read as object. Should be investigated before combining the datasets

# %% [markdown]
# ---

# %% [markdown]
# #### Investigate 2020 Start Time & End Time
# #### (Update if appropriate)

# %% [markdown]
# In 2020, Start Time and End Time are read as object. Should be investigated before combining the datasets

# %%
#Check if Trip ID are unique in df_2020
df_2020['Trip Id'].duplicated().sum()

# zero if all unique
# Out:
# 0

# %% [markdown]
# *Start Time*

# %%
# Check for Null values
df_2020['Start Time'].isna().sum()
# Out:
# 0

# %%
df_temp = pd.to_datetime(df_2020['Start Time'], errors='coerce')
df_temp
# Out:
# 0       2020-01-01 00:08:00
# 1       2020-01-01 00:10:00
# 2       2020-01-01 00:13:00
# 3       2020-01-01 00:17:00
# 4       2020-01-01 00:19:00
#                 ...
# 95343   2020-12-31 23:52:00
# 95344   2020-12-31 23:54:00
# 95345   2020-12-31 23:54:00
# 95346   2020-12-31 23:56:00
# 95347   2020-12-31 23:57:00
# Name: Start Time, Length: 2911308, dtype: datetime64[ns]

# %%
# Check how many rows are impacted
df_temp.isna().sum()
# Out:
# 249

# %%
df_2020[df_temp.isna()]
# Out:
#             Trip Id  Trip  Duration  Start Station Id  \
# 25640   10000084625            7120  10/03/2020 13:28
# 25837   10000306555            7120  10/03/2020 13:38
# 26029   10000519608            7576  10/03/2020 13:48
# 26248   10000755851            7357  10/03/2020 13:58
# 26560   10001076784            7313  10/03/2020 14:12
# ...             ...             ...               ...
# 266879  10281521317            7417  10/30/2020 17:01
# 268551  10283383488            7017  10/30/2020 19:42
# 275974  10291748450            7417  10/31/2020 18:00
# 277412  10293410950            7474  10/31/2020 21:27
# 277472  10293474102            7015  10/31/2020 21:43
#
#                               Start Time Start Station Name    End Station Id  \
# 25640            Gerrard St E / River St               7120  10/03/2020 13:38
# 25837            Gerrard St E / River St               7576  10/03/2020 13:48
# 26029        Front St E / Bayview Avenue               7357  10/03/2020 13:58
# 26248      Lake Shore Blvd E / Leslie St               7313  10/03/2020 14:12
# 26560   Coxwell Ave /  Lake Shore Blvd E               7317  10/03/2020 14:26
# ...                                  ...                ...               ...
# 266879             King St W / Jordan St               7253  10/30/2020 17:06
# 268551         Widmer St / Adelaide St W               7417  10/30/2020 19:50
# 275974             King St W / Jordan St               7474  10/31/2020 18:07
# 277412                   Clarence Square               7015  10/31/2020 21:42
# 277472    King St W / Bay St (West Side)               7417  10/31/2020 21:44
#
#                                 End Time End Station Name        Bike Id  \
# 25640            Gerrard St E / River St             5250  Annual Member
# 25837        Front St E / Bayview Avenue             5250  Annual Member
# 26029      Lake Shore Blvd E / Leslie St             5250  Annual Member
# 26248   Coxwell Ave /  Lake Shore Blvd E             5250  Annual Member
# 26560           Hubbard Blvd / Balsam Av             5250  Annual Member
# ...                                  ...              ...            ...
# 266879      John St  / Mercer St - SMART             4888  Annual Member
# 268551             King St W / Jordan St             5835  Annual Member
# 275974                   Clarence Square             3814  Annual Member
# 277412    King St W / Bay St (West Side)             3771  Annual Member
# 277472             King St W / Jordan St             3771  Annual Member
#
#        User Type
# 25640       <NA>
# 25837       <NA>
# 26029       <NA>
# 26248       <NA>
# 26560       <NA>
# ...          ...
# 266879      <NA>
# 268551      <NA>
# 275974      <NA>
# 277412      <NA>
# 277472      <NA>
#
# [249 rows x 10 columns]

# %%
st_trip_ids = df_2020[df_temp.isna()]['Trip Id'].sort_values()

# %% [markdown]
# *End Time*

# %%
# Check for Null values
df_2022['End Time'].isna().sum()
# Out:
# 0

# %%
df_temp_et = pd.to_datetime(df_2020['End Time'], errors='coerce')
df_temp_et
# Out:
# 0       2020-01-01 00:19:00
# 1       2020-01-01 00:17:00
# 2       2020-01-01 00:22:00
# 3       2020-01-01 00:38:00
# 4       2020-01-01 00:34:00
#                 ...
# 95343   2020-12-31 23:57:00
# 95344   2020-12-31 23:58:00
# 95345   2020-12-31 23:58:00
# 95346   2021-01-01 00:24:00
# 95347   2020-12-31 23:58:00
# Name: End Time, Length: 2911308, dtype: datetime64[ns]

# %%
# Check how many rows are impacted
df_temp_et.isna().sum()
# Out:
# 249

# %%
df_2020[df_temp_et.isna()]
# Out:
#             Trip Id  Trip  Duration  Start Station Id  \
# 25640   10000084625            7120  10/03/2020 13:28
# 25837   10000306555            7120  10/03/2020 13:38
# 26029   10000519608            7576  10/03/2020 13:48
# 26248   10000755851            7357  10/03/2020 13:58
# 26560   10001076784            7313  10/03/2020 14:12
# ...             ...             ...               ...
# 266879  10281521317            7417  10/30/2020 17:01
# 268551  10283383488            7017  10/30/2020 19:42
# 275974  10291748450            7417  10/31/2020 18:00
# 277412  10293410950            7474  10/31/2020 21:27
# 277472  10293474102            7015  10/31/2020 21:43
#
#                               Start Time Start Station Name    End Station Id  \
# 25640            Gerrard St E / River St               7120  10/03/2020 13:38
# 25837            Gerrard St E / River St               7576  10/03/2020 13:48
# 26029        Front St E / Bayview Avenue               7357  10/03/2020 13:58
# 26248      Lake Shore Blvd E / Leslie St               7313  10/03/2020 14:12
# 26560   Coxwell Ave /  Lake Shore Blvd E               7317  10/03/2020 14:26
# ...                                  ...                ...               ...
# 266879             King St W / Jordan St               7253  10/30/2020 17:06
# 268551         Widmer St / Adelaide St W               7417  10/30/2020 19:50
# 275974             King St W / Jordan St               7474  10/31/2020 18:07
# 277412                   Clarence Square               7015  10/31/2020 21:42
# 277472    King St W / Bay St (West Side)               7417  10/31/2020 21:44
#
#                                 End Time End Station Name        Bike Id  \
# 25640            Gerrard St E / River St             5250  Annual Member
# 25837        Front St E / Bayview Avenue             5250  Annual Member
# 26029      Lake Shore Blvd E / Leslie St             5250  Annual Member
# 26248   Coxwell Ave /  Lake Shore Blvd E             5250  Annual Member
# 26560           Hubbard Blvd / Balsam Av             5250  Annual Member
# ...                                  ...              ...            ...
# 266879      John St  / Mercer St - SMART             4888  Annual Member
# 268551             King St W / Jordan St             5835  Annual Member
# 275974                   Clarence Square             3814  Annual Member
# 277412    King St W / Bay St (West Side)             3771  Annual Member
# 277472             King St W / Jordan St             3771  Annual Member
#
#        User Type
# 25640       <NA>
# 25837       <NA>
# 26029       <NA>
# 26248       <NA>
# 26560       <NA>
# ...          ...
# 266879      <NA>
# 268551      <NA>
# 275974      <NA>
# 277412      <NA>
# 277472      <NA>
#
# [249 rows x 10 columns]

# %%
et_trip_ids = df_2020[df_temp_et.isna()]['Trip Id'].sort_values()

# %% [markdown]
# *Start Time* vs *End Time*

# %%
# Check to see if the Trip IDs are the same
(~(st_trip_ids == et_trip_ids)).sum()
    # ~ works as "NOT" with boolean values, 
        # here it's used for a Pandas Series of Bool values, as NOT function itself does not work

# If they line up, then we should get zero from this cell
# Out:
# 0

# %% [markdown]
# *Clean or drop?*

# %%
# Number of trips
st_trip_ids.count()
# Out:
# 249

# %%
# Number of total trips in 2020
df_2020.shape[0]
# Out:
# 2911308

# %%
# Percentage of total trips with poor data
st_trip_ids.count() / df_2020.shape[0]
# Out:
# 8.552856654122477e-05

# %% [markdown]
# ##### Findings:
# This represents ~0% of the data. In more simple terms around 250 / 3 million.
#
# As this is insignificant when compared to 2020, and the remainder of the dataset. These rows are not worth the effort to correct and will be dropped.

# %% [markdown]
# *Drop*

# %%
# Expected total trips in 2020 after drop
df_2020.shape[0] - st_trip_ids.count()
# Out:
# 2911059

# %%
# Drop rows with misaligned data
df_2020 = df_2020[~df_2020['Trip Id'].isin(st_trip_ids)]
    # more specifically, filter them out and reassign it to df_2020

# %%
df_2020.shape
# Out:
# (2911059, 10)

# %%
# Convert to Date Time
df_2020['Start Time'] = pd.to_datetime(df_2020['Start Time'])
df_2020['End Time'] = pd.to_datetime(df_2020['End Time'])

# %%
# Check Conversion
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2911059 entries, 0 to 95347
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          datetime64[ns]
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            datetime64[ns]
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), datetime64[ns](2), string(7)
# memory usage: 247.1 MB

# %% [markdown]
# ---

# %% [markdown]
# ### Combine All data into one DataFrame

# %%
#Create list of dataframes
year_dfs = [df_2019, df_2020, df_2021, df_2022, df_2023]

# Combine list of dataframes
df_bike_share_trips_raw = pd.concat(year_dfs)

# %%
df_bike_share_trips_raw.head() #visualize
# Out:
#    Trip Id  Trip  Duration Start Station Id          Start Time  \
# 0  4581278            1547             7021 2019-01-01 00:08:00
# 1  4581279            1112             7160 2019-01-01 00:10:00
# 2  4581280             589             7055 2019-01-01 00:15:00
# 3  4581281             259             7012 2019-01-01 00:16:00
# 4  4581282             281             7041 2019-01-01 00:19:00
#
#                         Start Station Name End Station Id            End Time  \
# 0                       Bay St / Albert St           7233 2019-01-01 00:33:00
# 1                 King St W / Tecumseth St           7051 2019-01-01 00:29:00
# 2                   Jarvis St / Carlton St           7013 2019-01-01 00:25:00
# 3  Elizabeth St / Edward St (Bus Terminal)           7235 2019-01-01 00:20:00
# 4                     Edward St / Yonge St           7257 2019-01-01 00:24:00
#
#                           End Station Name Bike Id      User Type
# 0                 King / Cowan Ave - SMART    1296  Annual Member
# 1      Wellesley St E / Yonge St (Green P)    2947  Annual Member
# 2                 Scott St / The Esplanade    2293  Annual Member
# 3  Bay St / College St (West Side) - SMART     283  Annual Member
# 4             Dundas St W / St. Patrick St    1799  Annual Member

# %%
df_bike_share_trips_raw.shape
# Out:
# (19259368, 10)

# %%
# Check to see if total rows are as expected
i_total = 0

for i_df in year_dfs:
    i_total += i_df.shape[0]
    
print(i_total)
# Out:
# 19259368

# %%
# Check - should be zero
i_total - df_bike_share_trips_raw.shape[0]
# Out:
# 0

# %%
df_bike_share_trips_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19259368 entries, 0 to 257114
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Trip Id             string
#  1   Trip  Duration      Int64
#  2   Start Station Id    string
#  3   Start Time          datetime64[ns]
#  4   Start Station Name  string
#  5   End Station Id      string
#  6   End Time            datetime64[ns]
#  7   End Station Name    string
#  8   Bike Id             string
#  9   User Type           string
# dtypes: Int64(1), datetime64[ns](2), string(7)
# memory usage: 1.6 GB

# %%
df_bike_share_trips_raw.isna().sum()
# Out:
# Trip Id                    0
# Trip  Duration            16
# Start Station Id           0
# Start Time                 0
# Start Station Name    783014
# End Station Id          7947
# End Time                   0
# End Station Name      791926
# Bike Id                  276
# User Type                  0
# dtype: int64

# %%
# Write to CSV 
df_bike_share_trips_raw.to_csv("data/2019_to_2023_bike_ridership_raw.csv",
                               index = False) # don't include index as a separate column)

# This step is done to have a file that serves as a "check point"

# %% [markdown]
# ##### Findings:
# - Yearly dataframes successfully combined into one, spanning from 2019 to 2023
# - Exported compiled dataframe to csv for next workbook (1B Data Cleaning) to import.

# %% [markdown]
# ---
